# %%
import pandas as pd
import os

# Caminho do CSV
caminho_arquivo = os.path.join( "resultados_rentcars_SSA_2025-10-12_21h.csv")
df = pd.read_csv(caminho_arquivo, encoding="utf-8-sig")

# Filtrar apenas locadoras Localiza ou Movida
#df_filtrado = df[df['locadora'].isin(['Localiza', 'Movida'])]

# Mostrar as primeiras 20 linhas
#df_filtrado.head(20)
df.head(20)

# Ou mostrar todas (se não for muito grande)
# df_filtrado
# Out:
#        id                nome           afiliado  lp        locadora  \
# 0   56750           Fiat Mobi  Rentcars (Mobile)   0            Foco
# 1   56751         Peugeot 208  Rentcars (Mobile)   0            Foco
# 2    7575     Volkswagen Polo  Rentcars (Mobile)   0            Foco
# 3   18590      Chevrolet Spin  Rentcars (Mobile)   0            Foco
# 4    7507  Volkswagen T-Cross  Rentcars (Mobile)   0            Foco
# 5   40807     Renault Kardian  Rentcars (Mobile)   0            Foco
# 6   56752         Fiat Cronos  Rentcars (Mobile)   0            Foco
# 7     569         Fiat Cronos  Rentcars (Mobile)   0  Locadora Opaca
# 8    4878        Fiat Fiorino  Rentcars (Mobile)   0  Locadora Opaca
# 9   11280           Fiat Mobi  Rentcars (Mobile)   0  Locadora Opaca
# 10     36          Fiat Pulse  Rentcars (Mobile)   0  Locadora Opaca
# 11    313         Fiat Strada  Rentcars (Mobile)   0  Locadora Opaca
# 12  13763        Hyundai HB20  Rentcars (Mobile)   0  Locadora Opaca
# ...
